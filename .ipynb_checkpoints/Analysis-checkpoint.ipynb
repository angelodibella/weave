# %% [markdown]
# # Designing Quantum Error-Correcting Codes

# %%
import numpy as np

import model

# %%
rep_model = model.StabilizerModel(rounds=25)

rep_model.set_noise_qubits(0.02)
rep_model.set_noise_circuit(0.01)

rep_model.repetition_code(9)
rep_model.measure()

# %%
rep_model.display_samples()
rep_model.display_detector_samples()

# %%
rep_model.circuit.diagram("timeline-svg")

# %%
rep_model.print()

# %%
H1 = np.array(
    [[1, 1, 0],
     [0, 1, 1]]
)

H2 = np.array(
    [[1, 1, 0],
     [0, 1, 1]]
)

HX, HZ = model.generate_hypergraph_pcm(H1, H2)

print(HX.astype(int))
print()
print(HZ.astype(int))

# %%
import model
import stim

surface_code = model.StabilizerModel(rounds=1)
surface_code.surface_code(scale=(3, 3))
surface_code.measure()
surface_code.print()
# Out:
# M 1 7 3 5
# CX 0 1 2 1 4 1 0 3 6 3 4 3 2 5 8 5 4 5 6 7 8 7 4 7
# MR 1 7
# DETECTOR rec[-1] rec[-5]
# DETECTOR rec[-2] rec[-6]
# MR 3 5
# DETECTOR rec[-1] rec[-5]
# DETECTOR rec[-2] rec[-6]

# %%
surface_code.circuit.without_noise().diagram("timeline-svg")
# Out:
# <svg viewBox="0 0 1440 672"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L1408,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L1408,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L1408,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L1408,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L1408,320 " stroke="black"/>
# ...
